# %% [markdown]
# ## Aula 1

# %%
import pandas as pd

# %%
nomes_f = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=f')
nomes_m = pd.read_json('https://servicodados.ibge.gov.br/api/v1/censos/nomes/ranking?qtd=20&sexo=m')

# %%
nomes_f.head()
# Out:
#         nome  regiao      freq  rank sexo
# 0      MARIA       0  11694738     1    F
# 1        ANA       0   3079729     2    F
# 2  FRANCISCA       0    721637     3    F
# 3    ANTONIA       0    588783     4    F
# 4    ADRIANA       0    565621     5    F

# %%
nomes_m.head()
# Out:
#         nome  regiao     freq  rank sexo
# 0       JOSE       0  5732508     1    M
# 1       JOAO       0  2971935     2    M
# 2    ANTONIO       0  2567494     3    M
# 3  FRANCISCO       0  1765197     4    M
# 4     CARLOS       0  1483121     5    M

# %%
nomes_f.sample(5) # Pega 5 elementos aleatório do DataFrame
# Out:
#         nome  regiao    freq  rank sexo
# 10    SANDRA       0  479230    11    F
# 8   PATRICIA       0  529446     9    F
# 12    AMANDA       0  464624    13    F
# 14   JESSICA       0  456472    15    F
# 19   MARIANA       0  381778    20    F

# %%
nomes_m.sample(5)
# Out:
#        nome  regiao     freq  rank sexo
# 5     PAULO       0  1417907     6    M
# 4    CARLOS       0  1483121     5    M
# 15    BRUNO       0   663271    16    M
# 2   ANTONIO       0  2567494     3    M
# 13   DANIEL       0   706527    14    M

# %%
print('Quantidade de nomes: ' + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 40

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()
nomes.sample(5)
# Out:
#        nome
# 4    CARLOS
# 6    MARCIA
# 12   AMANDA
# 2   ANTONIO
# 4   ADRIANA

# %%
import numpy as np

# %%
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 40

# %%
nomes['id_aluno'] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno
# 11     CAMILA        38
# 2     ANTONIO        27
# 5       PAULO        28
# 5     JULIANA        12
# 2   FRANCISCA        13

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)
nomes
# Out:
#          nome  id_aluno                 dominio
# 0       MARIA         7  @dominiodoemail.com.br
# 1         ANA        11     @servicodoemail.com
# 2   FRANCISCA        13     @servicodoemail.com
# 3     ANTONIA        39     @servicodoemail.com
# 4     ADRIANA         6     @servicodoemail.com
# 5     JULIANA        12  @dominiodoemail.com.br
# 6      MARCIA        24     @servicodoemail.com
# 7    FERNANDA         2     @servicodoemail.com
# 8    PATRICIA        14     @servicodoemail.com
# 9       ALINE        21     @servicodoemail.com
# 10     SANDRA         9  @dominiodoemail.com.br
# 11     CAMILA        38  @dominiodoemail.com.br
# 12     AMANDA        25     @servicodoemail.com
# 13      BRUNA         8     @servicodoemail.com
# 14    JESSICA        19     @servicodoemail.com
# 15    LETICIA        40     @servicodoemail.com
# 16      JULIA         4     @servicodoemail.com
# 17    LUCIANA        32  @dominiodoemail.com.br
# 18    VANESSA        22  @dominiodoemail.com.br
# 19    MARIANA        17     @servicodoemail.com
# 0        JOSE        26     @servicodoemail.com
# 1        JOAO         5     @servicodoemail.com
# 2     ANTONIO        27  @dominiodoemail.com.br
# 3   FRANCISCO        36     @servicodoemail.com
# 4      CARLOS        30  @dominiodoemail.com.br
# 5       PAULO        28  @dominiodoemail.com.br
# 6       PEDRO        15  @dominiodoemail.com.br
# 7       LUCAS         1     @servicodoemail.com
# 8        LUIZ        10     @servicodoemail.com
# 9      MARCOS        16     @servicodoemail.com
# 10       LUIS        31  @dominiodoemail.com.br
# 11    GABRIEL        37     @servicodoemail.com
# 12     RAFAEL        33  @dominiodoemail.com.br
# 13     DANIEL        34  @dominiodoemail.com.br
# 14    MARCELO        23     @servicodoemail.com
# 15      BRUNO        20     @servicodoemail.com
# 16    EDUARDO        18     @servicodoemail.com
# 17     FELIPE        35  @dominiodoemail.com.br
# 18   RAIMUNDO        29     @servicodoemail.com
# 19    RODRIGO         3     @servicodoemail.com

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                        email
# 14  JESSICA        19     @servicodoemail.com   jessica@servicodoemail.com
# 12   AMANDA        25     @servicodoemail.com    amanda@servicodoemail.com
# 15  LETICIA        40     @servicodoemail.com   leticia@servicodoemail.com
# 19  RODRIGO         3     @servicodoemail.com   rodrigo@servicodoemail.com
# 0     MARIA         7  @dominiodoemail.com.br  maria@dominiodoemail.com.br

# %% [markdown]
# ## Aula 2

# %%
# !pip3 install html5lib
# !pip3 install lxml
# Out:
# Requirement already satisfied: html5lib in d:\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in d:\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: lxml in d:\anaconda3\lib\site-packages (4.6.3)

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'

# %%
cursos = pd.read_html(url)

# %%
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.rename(columns = {'Nome do curso': 'nome_do_curso'}, inplace = True)

# %%
cursos.head()
# Out:
#            nome_do_curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
cursos['id'] = cursos.index + 1

# %%
cursos.head()
# Out:
#            nome_do_curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# ## Aula 3

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size = total_alunos) * 1.5).astype(int)

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 13    BRUNA         8     @servicodoemail.com      bruna@servicodoemail.com
# 13   DANIEL        34  @dominiodoemail.com.br  daniel@dominiodoemail.com.br
# 14  MARCELO        23     @servicodoemail.com    marcelo@servicodoemail.com
# 17   FELIPE        35  @dominiodoemail.com.br  felipe@dominiodoemail.com.br
# 10   SANDRA         9  @dominiodoemail.com.br  sandra@dominiodoemail.com.br
#
#     matriculas
# 13           3
# 13           3
# 14           1
# 17           1
# 10           1

# %%
nomes.matriculas.describe()
# Out:
# count    40.000000
# mean      1.775000
# std       1.165476
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.250000
# max       6.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# D:\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='matriculas', ylabel='Density'>

# %%
nomes.matriculas.value_counts()
# Out:
# 1    24
# 3     7
# 2     6
# 4     2
# 6     1
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 10     LUIS        31  @dominiodoemail.com.br    luis@dominiodoemail.com.br
# 11  GABRIEL        37     @servicodoemail.com    gabriel@servicodoemail.com
# 14  JESSICA        19     @servicodoemail.com    jessica@servicodoemail.com
# 15    BRUNO        20     @servicodoemail.com      bruno@servicodoemail.com
# 13   DANIEL        34  @dominiodoemail.com.br  daniel@dominiodoemail.com.br
#
#     matriculas
# 10           3
# 11           3
# 14           1
# 15           4
# 13           3

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
    id = row.id_aluno
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id, np.random.choice(cursos.index, p = prob)]
        todas_matriculas.append(mat)
        
matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno', 'id_curso'])

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0         7         8
# 1         7         5
# 2        11         8
# 3        13        11
# 4        39        11

# %%
matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns = {'id_aluno': 'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                            4                Lógica de programação
# 2                            4                        Java para Web
# 3                            4                          C# para Web
# 4                            1                        Ruby on Rails
# 5                            6                     Cursos de Python
# 6                            1                        PHP com MySql
# 8                            9           Novas integrações com Java
# 9                            2                         TDD com Java
# 11                           4  Preparatório para certificação Java
# 12                           2                      Hardware básico
# 13                           2                Persistência com .NET
# 14                           7                  Desenvolvendo jogos
# 15                           7                     Análise de dados
# 17                           8                  Internet das coisas
# 19                           4                Boas práticas em Java
# 20                           6          Orientação objetos com Java

# %%
nomes.head()
# Out:
#         nome  id_aluno                 dominio                         email  \
# 0      MARIA         7  @dominiodoemail.com.br   maria@dominiodoemail.com.br
# 1        ANA        11     @servicodoemail.com        ana@servicodoemail.com
# 2  FRANCISCA        13     @servicodoemail.com  francisca@servicodoemail.com
# 3    ANTONIA        39     @servicodoemail.com    antonia@servicodoemail.com
# 4    ADRIANA         6     @servicodoemail.com    adriana@servicodoemail.com
#
#    matriculas
# 0           2
# 1           1
# 2           1
# 3           2
# 4           1

# %%
cursos.head()
# Out:
#             nome_do_curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns = {'id_aluno': 'quantidade_de_alunos'})

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                            4  Lógica de programação
# 2                            4          Java para Web
# 3                            4            C# para Web
# 4                            1          Ruby on Rails
# 5                            6       Cursos de Python

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                            4  Lógica de programação
# 2                            4          Java para Web
# 3                            4            C# para Web
# 4                            1          Ruby on Rails
# 5                            6       Cursos de Python

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index = False)

# %%
pd.read_csv('matriculas_por_curso.csv')
# Out:
#     quantidade_de_alunos                        nome_do_curso
# 0                      4                Lógica de programação
# 1                      4                        Java para Web
# 2                      4                          C# para Web
# 3                      1                        Ruby on Rails
# 4                      6                     Cursos de Python
# 5                      1                        PHP com MySql
# 6                      9           Novas integrações com Java
# 7                      2                         TDD com Java
# 8                      4  Preparatório para certificação Java
# 9                      2                      Hardware básico
# 10                     2                Persistência com .NET
# 11                     7                  Desenvolvendo jogos
# 12                     7                     Análise de dados
# 13                     8                  Internet das coisas
# 14                     4                Boas práticas em Java
# 15                     6          Orientação objetos com Java

# %%
matriculas_json = matriculas_por_curso.to_json()

# %%
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"1":4,"2":4,"3":4,"4":1,"5":6,"6":1,"8":9,"9":2,"11":4,"12":2,"13":2,"14":7,"15":7,"17":8,"19":4,"20":6},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","2":"Java para Web","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","6":"PHP com MySql","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","11":"Preparat\\u00f3rio para certifica\\u00e7\\u00e3o Java","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","17":"Internet das coisas","19":"Boas pr\\u00e1ticas em Java","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_html = matriculas_por_curso.to_html()

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Novas integrações com Java</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2</td>
#       <td>TDD com Java</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>4</td>
#       <td>Preparatório para certificação Java</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2</td>
#       <td>Hardware básico</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2</td>
#       <td>Persistência com .NET</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>7</td>
#       <td>Desenvolvendo jogos</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>7</td>
#       <td>Análise de dados</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>8</td>
#       <td>Internet das coisas</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>4</td>
#       <td>Boas práticas em Java</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>6</td>
#       <td>Orientação objetos com Java</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Aula 4

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in d:\anaconda3\lib\site-packages (1.4.22)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda3\lib\site-packages (from sqlalchemy) (1.1.1)

# %%
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
matriculas_por_curso.to_sql('matriculas', engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas']
# C:\Users\MARCEL~1\AppData\Local\Temp/ipykernel_12568/1043810782.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %%
query = 'select * from matriculas where quantidade_de_alunos < 20'

# %%
pd.read_sql(query, engine)
# Out:
#     id_curso  quantidade_de_alunos                        nome_do_curso
# 0          1                     4                Lógica de programação
# 1          2                     4                        Java para Web
# 2          3                     4                          C# para Web
# 3          4                     1                        Ruby on Rails
# 4          5                     6                     Cursos de Python
# 5          6                     1                        PHP com MySql
# 6          8                     9           Novas integrações com Java
# 7          9                     2                         TDD com Java
# 8         11                     4  Preparatório para certificação Java
# 9         12                     2                      Hardware básico
# 10        13                     2                Persistência com .NET
# 11        14                     7                  Desenvolvendo jogos
# 12        15                     7                     Análise de dados
# 13        17                     8                  Internet das coisas
# 14        19                     4                Boas práticas em Java
# 15        20                     6          Orientação objetos com Java

# %%
pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                     4
# 1                         Java para Web                     4
# 2                           C# para Web                     4
# 3                         Ruby on Rails                     1
# 4                      Cursos de Python                     6
# 5                         PHP com MySql                     1
# 6            Novas integrações com Java                     9
# 7                          TDD com Java                     2
# 8   Preparatório para certificação Java                     4
# 9                       Hardware básico                     2
# 10                Persistência com .NET                     2
# 11                  Desenvolvendo jogos                     7
# 12                     Análise de dados                     7
# 13                  Internet das coisas                     8
# 14                Boas práticas em Java                     4
# 15          Orientação objetos com Java                     6

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                     4
# 1                         Java para Web                     4
# 2                           C# para Web                     4
# 3                         Ruby on Rails                     1
# 4                      Cursos de Python                     6
# 5                         PHP com MySql                     1
# 6            Novas integrações com Java                     9
# 7                          TDD com Java                     2
# 8   Preparatório para certificação Java                     4
# 9                       Hardware básico                     2
# 10                Persistência com .NET                     2
# 11                  Desenvolvendo jogos                     7
# 12                     Análise de dados                     7
# 13                  Internet das coisas                     8
# 14                Boas práticas em Java                     4
# 15          Orientação objetos com Java                     6

# %%
muitas_matriculas.query('quantidade_de_alunos > 7')
# Out:
#                  nome_do_curso  quantidade_de_alunos
# 6   Novas integrações com Java                     9
# 13         Internet das coisas                     8

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']
# C:\Users\MARCEL~1\AppData\Local\Temp/ipykernel_12568/1043810782.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %% [markdown]
# ## Aula 5

# %%
matriculas_por_curso.head(20)
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                            4                Lógica de programação
# 2                            4                        Java para Web
# 3                            4                          C# para Web
# 4                            1                        Ruby on Rails
# 5                            6                     Cursos de Python
# 6                            1                        PHP com MySql
# 8                            9           Novas integrações com Java
# 9                            2                         TDD com Java
# 11                           4  Preparatório para certificação Java
# 12                           2                      Hardware básico
# 13                           2                Persistência com .NET
# 14                           7                  Desenvolvendo jogos
# 15                           7                     Análise de dados
# 17                           8                  Internet das coisas
# 19                           4                Boas práticas em Java
# 20                           6          Orientação objetos com Java

# %%
matriculas
# Out:
#     id_aluno  id_curso
# 0          7         8
# 1          7         5
# 2         11         8
# 3         13        11
# 4         39        11
# ..       ...       ...
# 66        29        17
# 67         3         8
# 68         3         6
# 69         3         2
# 70         3        15
#
# [71 rows x 2 columns]

# %%
id_curso = 5
proxima_turma = matriculas.query('id_curso == {}'.format(id_curso))
proxima_turma
# Out:
#     id_aluno  id_curso
# 1          7         5
# 16        25         5
# 22        40         5
# 40        30         5
# 56        34         5
# 59        23         5

# %%
nomes.sample(3)
# Out:
#      nome  id_aluno                 dominio                        email  \
# 8    LUIZ        10     @servicodoemail.com      luiz@servicodoemail.com
# 9  MARCOS        16     @servicodoemail.com    marcos@servicodoemail.com
# 6   PEDRO        15  @dominiodoemail.com.br  pedro@dominiodoemail.com.br
#
#    matriculas
# 8           1
# 9           1
# 6           2

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso     nome                 dominio  \
# id_aluno
# 7                5    MARIA  @dominiodoemail.com.br
# 25               5   AMANDA     @servicodoemail.com
# 40               5  LETICIA     @servicodoemail.com
# 30               5   CARLOS  @dominiodoemail.com.br
# 34               5   DANIEL  @dominiodoemail.com.br
# 23               5  MARCELO     @servicodoemail.com
#
#                                  email  matriculas
# id_aluno
# 7          maria@dominiodoemail.com.br           2
# 25           amanda@servicodoemail.com           3
# 40          leticia@servicodoemail.com           2
# 30        carlos@dominiodoemail.com.br           3
# 34        daniel@dominiodoemail.com.br           3
# 23          marcelo@servicodoemail.com           1

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome']
# Out:
# id_aluno
# 7       MARIA
# 25     AMANDA
# 40    LETICIA
# 30     CARLOS
# 34     DANIEL
# 23    MARCELO
# Name: nome, dtype: object

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
# Out:
#              nome
# id_aluno
# 7           MARIA
# 25         AMANDA
# 40        LETICIA
# 30         CARLOS
# 34         DANIEL
# 23        MARCELO

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# nome_do_curso    Cursos de Python
# Name: 5, dtype: object

# %%
nome_curso = nome_curso.nome_do_curso
nome_curso
# Out:
# 'Cursos de Python'

# %%
proxima_turma = proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()

# %%
proxima_turma
# Out:
#              nome
# id_aluno
# 7           MARIA
# 25         AMANDA
# 40        LETICIA
# 30         CARLOS
# 34         DANIEL
# 23        MARCELO

# %%
proxima_turma.rename(columns = {'nome': 'Alunos do curso de {}'.format(nome_curso)}, inplace = True)

# %%
proxima_turma
# Out:
#          Alunos do curso de Cursos de Python
# id_aluno
# 7                                      MARIA
# 25                                    AMANDA
# 40                                   LETICIA
# 30                                    CARLOS
# 34                                    DANIEL
# 23                                   MARCELO

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index = False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#   Alunos do curso de Cursos de Python
# 0                               MARIA
# 1                              AMANDA
# 2                             LETICIA
# 3                              CARLOS
# 4                              DANIEL
# 5                             MARCELO
